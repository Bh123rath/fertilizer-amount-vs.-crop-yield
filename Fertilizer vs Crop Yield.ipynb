# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
df=pd.read_excel(r"C:\Users\aaa\Downloads\Fertilizers.xlsx")
x=df['Fertilizer'].values.reshape(-1,1)
y=df['Yield'].values
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
plt.scatter(x,y,color='blue')
plt.xlabel('Fertilizer kg per hectare', color='Purple')
plt.ylabel('Crop Yield tons per hectare',color='green')
plt.title('Polynomial Regression: Fertilizer vs Crop Yield',color='black')
plt.plot(x,y_pred,color='red')
plt.show()
